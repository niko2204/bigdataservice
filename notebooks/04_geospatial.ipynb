# %% [markdown]
# # 04. 공간 시각화

# %%
import pandas as pd, folium
df = pd.read_csv('../data/sample/location_features.csv')
m = folium.Map([34.804, 126.414], zoom_start=13)
for _, r in df.iterrows():
    folium.CircleMarker([r['위도'],r['경도']], radius=5+r['유동인구']/2500, tooltip=r['행정동명']).add_to(m)
m
