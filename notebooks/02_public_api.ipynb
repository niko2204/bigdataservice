# %% [markdown]
# # 02. 공공데이터 API
# 인증키는 코드에 적지 말고 Colab 보안 비밀 또는 환경변수를 사용합니다.

# %%
import os, requests
API_KEY = os.getenv('DATA_GO_KR_API_KEY')
BASE_URL = 'https://apis.data.go.kr/B553077/api/open/sdsc2/storeListInRadius'
params = {'serviceKey': API_KEY, 'cx': 126.3922, 'cy': 34.8118, 'radius': 1000, 'pageNo': 1, 'numOfRows': 10, 'type': 'json'}
# API_KEY를 설정한 뒤 다음 주석을 해제하세요.
# response = requests.get(BASE_URL, params=params, timeout=20)
# response.raise_for_status()
# response.json()
