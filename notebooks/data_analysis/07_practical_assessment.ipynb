# %% [markdown]
# # Lab 07. 개인별 데이터 분석 종합 실기
# ## 규칙
# 학번을 입력하고 모든 셀을 순서대로 실행한다. 코드, 중간 결과, 그래프, 해석을 남긴다. 제출 후 교수자가 변수·조건을 바꾸어 재실행하도록 요청한다.
#
# 권장 시간: 독립 분석 90분 + 개인 확인 8분

# %%
from pathlib import Path
import sys, pandas as pd, numpy as np, matplotlib.pyplot as plt
ROOT=Path.cwd()
if not (ROOT/'src').exists(): ROOT=(ROOT/'../..').resolve()
sys.path.insert(0,str(ROOT))
from src.education.personalized_data import make_student_dataset
STUDENT_ID='학번입력'
NAME='이름입력'
df=make_student_dataset(STUDENT_ID)
print(NAME, STUDENT_ID, df.shape)
display(df.sample(5, random_state=1))

# %% [markdown]
# ## 문제 1. 품질 진단과 전처리(20점)
# 결측, 중복, 이상값을 탐지한다. 처리 방법을 최소 두 가지 비교한 후 최종 방법을 선택하라. 처리 전후 행 수와 월매출 평균·중앙값·표준편차를 표로 제시하라.

# %%
# 답안 1
quality_report = None
clean = None
display(quality_report)

# %% [markdown]
# ## 문제 2. 기술통계와 손계산(20점)
# 월매출 첫 5개 값의 평균과 표본분산을 공식대로 계산하고 pandas 결과와 비교하라. 업종별 기술통계표를 작성하고 차이를 해석하라.

# %%
# 답안 2
first5 = None
manual_mean = None
manual_variance = None
group_summary = None

# %% [markdown]
# ## 문제 3. 추론 또는 관계 분석(20점)
# 스스로 질문 하나를 정한다. 신뢰구간, 두 집단 검정, 상관 중 적절한 방법을 선택하고 가정·수치·효과크기·한계를 설명하라.

# %%
# 분석 질문:
# 선택 방법과 이유:
# 답안 3

# %% [markdown]
# ## 문제 4. 모델링(20점)
# 회귀 또는 군집 중 하나를 선택한다. 학습·평가 절차 또는 k 선택 절차를 제시하고 최소 두 지표로 결과를 검증하라.

# %%
# 선택 모델:
# 답안 4

# %% [markdown]
# ## 문제 5. 시각화와 의사결정(20점)
# 분석 질문에 답하는 그래프 두 개를 만들고 제목, 단위, 범례를 표시한다. 관찰·해석·한계를 구분해 작성하고 이 결과로 가능한 결정과 불가능한 결정을 각각 제시하라.

# %%
# 답안 5

# %% [markdown]
# ## 제출 체크
# - [ ] Restart & Run All이 오류 없이 끝난다.
# - [ ] 학번과 이름이 있다.
# - [ ] 모든 수치에 단위가 있다.
# - [ ] 처리 선택의 근거와 대안 비교가 있다.
# - [ ] 그래프마다 관찰·해석·한계가 있다.
# - [ ] AI나 외부 자료를 사용한 부분을 출처와 함께 표시했다.
# - [ ] 구두 확인에서 코드를 수정할 준비가 되었다.
