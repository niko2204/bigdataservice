# %% [markdown]
# # Lab 02. 기술통계와 표준점수
# 평균은 중심, 분산과 표준편차는 흩어진 정도를 나타낸다.
#
# 표본분산: s^2 = sum((x_i-x_bar)^2)/(n-1), z점수: z_i=(x_i-x_bar)/s
#
# pandas의 std 기본값은 ddof=1이며 표본표준편차를 계산한다.

# %%
from pathlib import Path
import sys, pandas as pd, numpy as np
ROOT=Path.cwd()
if not (ROOT/'src').exists(): ROOT=(ROOT/'../..').resolve()
sys.path.insert(0,str(ROOT))
from src.education.personalized_data import make_student_dataset
STUDENT_ID='학번입력'
df=make_student_dataset(STUDENT_ID).drop_duplicates()
x=df['월매출'].dropna().to_numpy()
x[:5]

# %%
# TODO 1: 공식대로 표본분산을 계산하고 np.var(x, ddof=1)과 비교하세요.
x_bar = None
squared_sum = None
sample_variance = None
sample_std = None
print(sample_variance, np.var(x, ddof=1))

# %%
# TODO 2: 월매출 z점수를 만들고 |z|>3인 행을 찾으세요.
sales_mean = None
sales_std = None
df['매출_z'] = None
extreme = None
display(extreme)

# %%
# TODO 3: 업종별 개수, 평균, 중앙값, 표준편차를 한 표로 만드세요.
summary = None
display(summary)

# %% [markdown]
# ## 해석
# 1. 평균과 중앙값 차이가 가장 큰 업종은 무엇이며 왜 그런가?
# 2. ddof=0과 ddof=1 결과 차이는 표본 크기가 커질수록 어떻게 변하는가?
# 3. z점수만으로 이상값을 삭제하면 안 되는 이유는?
