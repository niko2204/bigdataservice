# %% [markdown]
# # Lab 01. 데이터 품질과 전처리
# ## 이론
# 결측값은 관측되지 않은 값, 중복은 같은 관측의 반복이다. 이상값은 무조건 오류가 아니므로 원인과 분석 목적을 확인한다.
#
# IQR = Q3 - Q1, 일반적인 경계는 [Q1-1.5 IQR, Q3+1.5 IQR]이다.

# %%
from pathlib import Path
import sys, pandas as pd, numpy as np
ROOT = Path.cwd()
if not (ROOT / 'src').exists(): ROOT = (ROOT / '../..').resolve()
sys.path.insert(0, str(ROOT))
from src.education.personalized_data import make_student_dataset
STUDENT_ID = '학번입력'
df = make_student_dataset(STUDENT_ID)
print(df.shape)
display(df.head())

# %%
# TODO 1: 열별 자료형, 결측 수, 중복 수를 출력하세요.
print(df.dtypes)
missing = None
duplicates = None
print(missing, duplicates)

# %%
# TODO 2: 월매출의 Q1, Q3, IQR과 이상값 행 번호를 계산하세요.
q1 = None
q3 = None
iqr = None
lower, upper = None, None
outliers = None
display(outliers)

# %%
# TODO 3: 중복을 제거하고 유동인구·월임대료 결측값을 처리하세요.
# 평균, 중앙값, 그룹별 중앙값 중 하나를 선택하고 이유를 작성하세요.
clean = df.copy()
clean = None
assert clean is not None
assert clean.duplicated().sum() == 0
assert clean[['유동인구','월임대료']].isna().sum().sum() == 0

# %% [markdown]
# ## 제출 기록
# - 원본 행 수 / 정제 후 행 수:
# - 결측 처리 방법과 근거:
# - 이상값 처리 여부와 근거:
# - 다른 방법을 사용했을 때 평균·중앙값이 어떻게 달라지는가?
